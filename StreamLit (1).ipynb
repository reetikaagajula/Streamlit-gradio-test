# %%
# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1 --quiet
from pyngrok import ngrok
# Out:
#      |████████████████████████████████| 9.2 MB 5.3 MB/s
#      |████████████████████████████████| 4.7 MB 40.0 MB/s
#      |████████████████████████████████| 182 kB 58.7 MB/s
#      |████████████████████████████████| 78 kB 5.3 MB/s
#      |████████████████████████████████| 164 kB 60.3 MB/s
#      |████████████████████████████████| 237 kB 52.8 MB/s
#      |████████████████████████████████| 63 kB 1.3 MB/s
#      |████████████████████████████████| 51 kB 5.2 MB/s
# ...

# %%
# %%writefile app.py
import streamlit as st 
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from PIL import image,ImageOps
import tensorflow as tf 
from tensorflow.keras.models import load_model
from io import StringIO

model = load_model('Language_detection.pkl')

st.title("Language Detection using NLP")

sentence = st.text_input("Enter the text here:")

def prediction(text):
    x = cv.transform([text]).toarray()
    lang = model.predict(x)
    lang = le.inverse_transform(lang)
    st.write("The langauge is in",lang[0])

if sentence:
  st.write(model.prediction(sentence))
else:
  st.write("Please enter the text")
# Out:
# Overwriting app.py

# %%
# !ngrok authtoken 2HiVcdvB2wg3fqTXeST4iJR7Cos_6fKTtdBAMgUhPAWkR5Ht5
# !nohup streamlit run app.py &

url = ngrok.connect(port = 8501)
print(url)
# !streamlit run --server.port http ngrok 80 app.py >/dev/null
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml
# nohup: appending output to 'nohup.out'
# WARNING:pyngrok.process:t=2022-11-18T10:52:08+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=f66a83949c321a4b err="Your account may not run more than 3 tunnels over a single ngrok agent session.\nThe tunnels already running on this session are:\ntn_2HiViRCHI8245qUhCzZioya24uo, tn_2HiX9pheT2qOnOolFfur7bpDACD, tn_2HiViQSD3blZTgPjLQVF9NOtJvf\n\r\n\r\nERR_NGROK_324\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout)
#     288     try:
# --> 289         response = urlopen(request, data, timeout)
#     290         response_data = response.read().decode("utf-8")
#
# ...
